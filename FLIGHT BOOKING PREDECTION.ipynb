# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Flight_Booking.csv')

# %%
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
plt.figure(figsize=(20,5))
sns.lineplot(df , x = df['days_left'] , y = df['price'] )
# Out:
# <Axes: xlabel='days_left', ylabel='price'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(df , x = df['class'] , y = df['price'] , hue=df['airline'] )
# Out:
# <Axes: xlabel='class', ylabel='price'>

# %%
plt.figure(figsize=(20,5))
sns.barplot(df , x = df['airline'] , y = df['price'] , hue=df['class'] )
# Out:
# <Axes: xlabel='airline', ylabel='price'>

# %%
fig,ax = plt.subplots(2 ,1,figsize=(20 ,20))
sns.lineplot(df , x = df['days_left'] , y = df['price']  , hue = 'destination_city' , ax=ax[0])
sns.lineplot(df , x = df['days_left'] , y = df['price']  , hue = 'source_city' , ax=ax[1])
# Out:
# <Axes: xlabel='days_left', ylabel='price'>

# %%
plt.figure(figsize = (20 ,20))

plt.subplot(3, 2 ,1)
sns.countplot(data = df , x = df['airline'])
plt.title('AIRLINES')


plt.subplot(3, 2, 2)
sns.countplot(data = df , x = df['class'])
plt.title('CLASS')


plt.subplot(3, 2 ,3 )
sns.countplot(data = df , x = df['source_city'])
plt.title('SOURCE CITYS')

plt.subplot(3, 2, 4)
sns.countplot(data = df , x = df['destination_city'])
plt.title('DESTINATION CITIES')


plt.subplot(3, 2, 5)
sns.countplot(data = df , x = df['departure_time'])
plt.title('DEPARTURE TIME')


plt.subplot(3, 2, 6)
sns.countplot(data = df , x = df['arrival_time'])
plt.title('ARRIVAL TIME')
# Out:
# Text(0.5, 1.0, 'ARRIVAL TIME')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
sns.countplot(data =df , x = df['stops'])
# Out:
# <Axes: xlabel='stops', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['airline'] = le.fit_transform(df['airline'])
df['source_city'] = le.fit_transform(df['source_city'])
df['departure_time'] = le.fit_transform(df['departure_time'])
df['stops'] = le.fit_transform(df['stops'])
df['arrival_time'] = le.fit_transform(df['arrival_time'])
df['destination_city'] = le.fit_transform(df['destination_city'])
df['class'] = le.fit_transform(df['class'])

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df.drop(['Unnamed: 0'] ,axis = 1, inplace = True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in df.columns:
    if (df[col].dtype != 'object' and  col != "price"):
        col_list.append(col)
        
        
vif = pd.DataFrame()

# %%
x = df[col_list]
vif['features'] = x.columns
vif['vif'] = [variance_inflation_factor(x.values , i) for i in range(len(x.columns))]

# %%
print(vif)
# Out:
#            features       vif
# 0           airline  3.393124
# 1       source_city  2.927766
# 2    departure_time  2.779427
# 3             stops  1.426614
# 4      arrival_time  3.684550
# 5  destination_city  2.885337
# 6             class  2.849370
# 7          duration  4.113876
# 8         days_left  3.976790

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import StandardScaler

# %%
X = df.drop(columns = ['price' , 'flight'])

# %%
X
# Out:
#         airline  source_city  departure_time  stops  arrival_time  \
# 0             4            2               2      2             5
# 1             4            2               1      2             4
# 2             0            2               1      2             1
# 3             5            2               4      2             0
# 4             5            2               4      2             4
# ...         ...          ...             ...    ...           ...
# 300148        5            1               4      0             2
# 300149        5            1               0      0             5
# 300150        5            1               1      0             5
# 300151        5            1               1      0             2
# 300152        5            1               4      0             2
#
#         destination_city  class  duration  days_left
# 0                      5      1      2.17          1
# 1                      5      1      2.33          1
# ...

# %%
Y = df['price']

# %%
Y
# Out:
# 0          5953
# 1          5953
# 2          5956
# 3          5955
# 4          5955
#           ...
# 300148    69265
# 300149    77105
# 300150    79099
# 300151    81585
# 300152    81585
# Name: price, Length: 300153, dtype: int64

# %%
x_train , x_test , y_train , y_test  = train_test_split(X , Y, test_size=0.2 , shuffle=True)

# %%
sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
lr  = LinearRegression()

lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
diff = pd.DataFrame(np.c_[y_test ,y_pred] , columns=['actual value' , 'predicted value'])

# %%
diff
# Out:
#        actual value  predicted value
# 0            3000.0     -1874.621788
# 1           58125.0     52672.803777
# 2            3671.0      7263.142461
# 3           82553.0     48456.700516
# 4           15551.0      9580.084286
# ...             ...              ...
# 60026        7596.0      2123.213548
# 60027        7488.0      1610.645899
# 60028       60260.0     53504.614457
# 60029        3096.0       578.720289
# 60030        6618.0      1373.385134
#
# [60031 rows x 2 columns]

# %%
from sklearn.metrics import r2_score , mean_absolute_error , mean_squared_error

# %%
print(r2_score(y_test , y_pred)*100)

print(mean_absolute_error(y_test , y_pred))

print(np.sqrt(mean_squared_error(y_test , y_pred)))
# Out:
# 90.34337182157168
# 4647.240994331615
# 7040.98057140974

# %%
sns.histplot(y_test , label = 'actual')
sns.histplot(y_pred , label = 'predicted')
plt.legend()
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()

dt.fit(x_train , y_train)

dt_y_pred = dt.predict(x_test)

# %%
print(r2_score(y_test , dt_y_pred)*100)

print(mean_absolute_error(y_test , dt_y_pred))

print(np.sqrt(mean_squared_error(y_test , dt_y_pred)))
# Out:
# 96.8560140270711
# 1412.339627303671
# 4017.5444552605536

# %%
sns.distplot(y_test , label = 'actual')
sns.distplot(dt_y_pred , label = 'predicted')
plt.legend()
plt.show()
# Out:
# C:\Users\Ravi Shankar Vadali\AppData\Local\Temp\ipykernel_4796\1134947500.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test , label = 'actual')
# C:\Users\Ravi Shankar Vadali\AppData\Local\Temp\ipykernel_4796\1134947500.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rt = RandomForestRegressor()

# %%
rt.fit(x_train , y_train)
# Out:
# RandomForestRegressor()

# %%
rt_y_pred = rt.predict(x_test)

# %%
# Out:
# 98.00203536582292
# 1304.033796100454
# 3202.6854698383904

# %%
sns.distplot(y_test , label = 'actual')
sns.distplot(rt_y_pred , label = 'predicted')
plt.legend()
plt.show()
# Out:
# C:\Users\Ravi Shankar Vadali\AppData\Local\Temp\ipykernel_4796\973342554.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test , label = 'actual')
# C:\Users\Ravi Shankar Vadali\AppData\Local\Temp\ipykernel_4796\973342554.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
print("LINEAR REGRESSION")

print(r2_score(y_test , y_pred)*100)

print(mean_absolute_error(y_test , y_pred))

print(np.sqrt(mean_squared_error(y_test , y_pred)) , '\n')


print("DECISION TREE")

print(r2_score(y_test , dt_y_pred)*100)

print(mean_absolute_error(y_test , dt_y_pred))

print(np.sqrt(mean_squared_error(y_test , dt_y_pred)) , '\n')


print("RANDOM FOREST")
print(r2_score(y_test , rt_y_pred)*100)

print(mean_absolute_error(y_test , rt_y_pred))

print(np.sqrt(mean_squared_error(y_test , rt_y_pred)))
# Out:
# LINEAR REGRESSION
# 90.34337182157168
# 4647.240994331615
# 7040.98057140974
#
# DECISION TREE
# 96.8560140270711
# 1412.339627303671
# 4017.5444552605536
#
# RANDOM FOREST
# 98.00203536582292
# 1304.033796100454
# 3202.6854698383904
